# %% [markdown]
# ## Results of parameters line search for the GF dataset with a single replicate.
#
#
# ### Differences with previous experiment
#
# * Second experiment replicate was integrated.
# * First 100 frames were trimmed out of the dataset to remove early response.
# * Only trajectories with at least 240 points after trimming of early frames were kept.
#
# Also took in account some results from previous experiment. The models are still the same but some changes of default parameter:
# * There's a default L2 norm of 1e-3
# * The number of features before softmax was brought from 20 to 10
#
# ### Conclusions
#
# SImilar as for first experiment. Maybe could take a trajectory length of 220 instead of 200.

# %% [markdown]
# ### Results
#
# Logs from tensorboard were exported on the server where the models were trained and tuned into csv.
#
# Results are smoothed with a rolling average over 20 epochs.
#
# ### ERK model

# %%
import pandas as pd
from ggplot import *

df = pd.read_csv('../output/result_linesearch/ERK_repl2.csv')
df = df.melt(['linesearch_var', 'linesearch_val', 'step'])
df['color_var'] = df['linesearch_var'] + '_' + df['linesearch_val'].map(str)
df['smooth_value'] = df.groupby(['linesearch_var','linesearch_val', 'variable'])['value'].apply(lambda x:x.rolling(window=20, center=False).mean())
# Out:
# /home/marc/anaconda3/lib/python3.7/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,

# %% [markdown]
# #### Length

# %%
ggplot(df[df['linesearch_var']=='length'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (8780343605887)>

# %% [markdown]
# #### Number of features in layer before softmax

# %%
ggplot(df[df['linesearch_var']=='nfeatures'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() #+\
    #scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (-9223363256511598234)>

# %% [markdown]
# #### Batch size

# %%
ggplot(df[df['linesearch_var']=='batch_size'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (-9223363256510217584)>

# %% [markdown]
# #### L2 regularization

# %%
ggplot(df[df['linesearch_var']=='l2_norm'][df['linesearch_val']!=1],
       aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# /home/marc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# <ggplot: (-9223363256514290502)>

# %% [markdown]
# ### AKT model

# %%
import pandas as pd
from ggplot import *

df = pd.read_csv('../output/result_linesearch/AKT_repl2.csv')
df = df.melt(['linesearch_var', 'linesearch_val', 'step'])
df['color_var'] = df['linesearch_var'] + '_' + df['linesearch_val'].map(str)
df['smooth_value'] = df.groupby(['linesearch_var','linesearch_val', 'variable'])['value'].apply(lambda x:x.rolling(window=20, center=False).mean())

# %% [markdown]
# #### Length

# %%
ggplot(df[df['linesearch_var']=='length'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (8780340485345)>

# %% [markdown]
# #### Number of features in layer before softmax

# %%
ggplot(df[df['linesearch_var']=='nfeatures'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() #+\
    #scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (8780340287124)>

# %% [markdown]
# #### Batch size

# %%
ggplot(df[df['linesearch_var']=='batch_size'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (8780340147755)>

# %% [markdown]
# #### L2 regularization

# %%
ggplot(df[df['linesearch_var']=='l2_norm'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (-9223363256514822165)>

# %% [markdown]
# ### ERK-AKT model

# %%
import pandas as pd
from ggplot import *

df = pd.read_csv('../output/result_linesearch/ERK_AKT_repl2.csv')
df = df.melt(['linesearch_var', 'linesearch_val', 'step'])
df['color_var'] = df['linesearch_var'] + '_' + df['linesearch_val'].map(str)
df['smooth_value'] = df.groupby(['linesearch_var','linesearch_val', 'variable'])['value'].apply(lambda x:x.rolling(window=20, center=False).mean())

# %% [markdown]
# #### Length

# %%
ggplot(df[df['linesearch_var']=='length'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (8780339536904)>

# %% [markdown]
# #### Number of features in layer before softmax

# %%
ggplot(df[df['linesearch_var']=='nfeatures'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() #+\
    #scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (8780339329884)>

# %% [markdown]
# #### Batch size

# %%
ggplot(df[df['linesearch_var']=='batch_size'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (8780326585373)>

# %% [markdown]
# #### L2 regularization

# %%
ggplot(df[df['linesearch_var']=='l2_norm'], aes(x='step', y='smooth_value', color='factor(color_var)')) +\
    geom_line(aes(group='linesearch_val'), alpha=0.75) +\
    facet_wrap('variable', scales='free_y', ncol=3) +\
    theme_bw() +\
    scale_color_brewer(type='qual', palette='Set1')
# Out:
# <ggplot: (-9223363256528905500)>
